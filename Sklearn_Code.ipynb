# %% [markdown]
# <a href="https://colab.research.google.com/github/PatolaMarkJoseph/BayesianStatistics/blob/main/Sklearn_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA

file_path = '/content/Unsupervised_Data.csv'
sample = pd.read_csv(file_path)
sample = sample.dropna()
sample = sample.head(150)

gender_label = LabelEncoder()
sample['Gender'] = gender_label.fit_transform(sample['Gender'])

X = data.drop(columns=["Id"])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

kmeans = KMeans(n_clusters=4, random_state=20)
cluster = kmeans.fit_predict(X_scaled)

sample['Cluster'] = cluster
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=sample['Cluster'])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('K-Means Clustering Results')
plt.show()

print(sample.head())
# Out:
#     Id   Age  Gender  Paracetamol  Acitaminophen  Aspirin  Ibuprofen  Tylenol  \
# 0  1.0  18.0       1         80.0           30.0     80.0       50.0     50.0
# 1  2.0  20.0       0         60.0           20.0     70.0       40.0     40.0
# 2  3.0  15.0       1         20.0           40.0     50.0       60.0     20.0
# 3  4.0  18.0       0         50.0           30.0     60.0       30.0     30.0
# 4  5.0  18.0       1         30.0           25.0     28.0       34.0     37.0
#
#    Diphen  Bronkaid  ...  Naproxen  Proprinal  Addaprin  Zebutal  Meperdine  \
# 0    60.0      40.0  ...      90.0       20.0      90.0     50.0       20.0
# 1    20.0      30.0  ...      70.0       40.0      80.0     60.0       30.0
# 2    70.0      50.0  ...      50.0       30.0      50.0     70.0       50.0
# 3    50.0      60.0  ...      60.0       60.0      40.0     80.0       40.0
# 4    40.0      80.0  ...      80.0       68.0      89.0     49.0       19.0
#
# ...
